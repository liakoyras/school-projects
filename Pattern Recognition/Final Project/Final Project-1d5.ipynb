# %% [markdown]
# # CIFAR-10 Classification with CNN

# %%
import torch
import torchvision
from torchvision import datasets

from torch import nn
from torch import optim

from torch.utils.data import Dataset, DataLoader
from torchvision.transforms import ToTensor

import math
import numpy as np
import matplotlib.pyplot as plt

import neural_nets
import cnn_utils as util

# %%
torch.manual_seed(42)

# %% [markdown]
# ## Import Data

# %% [markdown]
# ### Download Dataset

# %%
training_data = datasets.CIFAR10(
    root="data",
    train=True,
    download=True,
    transform=ToTensor()
)

test_data = datasets.CIFAR10(
    root="data",
    train=False,
    download=True,
    transform=ToTensor()
)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# ### Create Loaders

# %% [markdown]
# This step is needed in order to automate the loading of images with set batch size.

# %%
batch_size = 256

# %%
train_loader = torch.utils.data.DataLoader(dataset=training_data,
                                           batch_size=batch_size,
                                           shuffle=True)

test_loader = torch.utils.data.DataLoader(dataset=test_data,
                                          batch_size=batch_size,
                                          shuffle=True)

# %% [markdown]
# ### Set general parameters

# %%
input_dimensions = (32,32)
target_classes = 10

# %% [markdown]
# # Best Model Analysis

# %% [markdown]
# In order to study the best models and determine whether or not they are affected by overfitting, we need to train them for more epochs and view the correlation between train loss and test accuracy during each epoch.

# %% [markdown]
# ### Training hyperparameters

# %%
num_epochs = 50
learning_rate = 0.001

# %% [markdown]
# ## 3 conv + 1 fc layer model

# %%
cnn_1 = neural_nets.CNN(n_conv_layers=3,
                        filters=[64, 128, 256],
                        kernel=[3, 3, 3],
                        activation=['relu', 'relu', 'relu'],
                        norm=[False, False, False],
                        pool=[2, 2, 2],
                        input_channels=3,
                        fully_connected= [64],
                        input_dims=input_dimensions,
                        classes=target_classes)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print(cnn_1)
print()
total_params = sum([math.prod(list(p.size())) for p in list(cnn_1.parameters())])
print("Total number of parameters:", total_params)
# Out:
# CNN(
#   (conv_layers): ModuleList(
#     (0): Sequential(
#       (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=same)
#       (1): ReLU()
#       (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#     (1): Sequential(
#       (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=same)
#       (1): ReLU()
#       (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#     (2): Sequential(
#       (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=same)
#       (1): ReLU()
#       (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#   )
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (fc_layers): ModuleList(
#     (0): Linear(in_features=4096, out_features=64, bias=True)
#     (1): Linear(in_features=64, out_features=10, bias=True)
#   )
# )
#
# Total number of parameters: 633674

# %% [markdown]
# ### Train

# %%
# %%time
cross_entropy = nn.CrossEntropyLoss()
adam_1 = optim.Adam(cnn_1.parameters(), lr=learning_rate)

losses_1, accuracies_1 = util.train_loop(model=cnn_1,
                                         loss_fn=cross_entropy,
                                         optimizer=adam_1,
                                         train_loader=train_loader,
                                         test_loader=test_loader,
                                         epochs=num_epochs,
                                         verbose=1)
# Out:
# Epoch: 1/50, Loss: 1.4399
# Epoch: 1/50, Test Acc.: 50.79%
# Epoch: 2/50, Loss: 0.9472
# Epoch: 2/50, Test Acc.: 62.25%
# Epoch: 3/50, Loss: 0.8929
# Epoch: 3/50, Test Acc.: 67.93%
# Epoch: 4/50, Loss: 0.7857
# Epoch: 4/50, Test Acc.: 67.26%
# Epoch: 5/50, Loss: 0.7769
# Epoch: 5/50, Test Acc.: 67.63%
# Epoch: 6/50, Loss: 0.8474
# Epoch: 6/50, Test Acc.: 73.33%
# Epoch: 7/50, Loss: 0.5215
# Epoch: 7/50, Test Acc.: 74.66%
# Epoch: 8/50, Loss: 0.6272
# Epoch: 8/50, Test Acc.: 73.84%
# Epoch: 9/50, Loss: 0.4324
# Epoch: 9/50, Test Acc.: 73.92%
# Epoch: 10/50, Loss: 0.5539
# Epoch: 10/50, Test Acc.: 75.10%
# Epoch: 11/50, Loss: 0.3648
# Epoch: 11/50, Test Acc.: 74.93%
# Epoch: 12/50, Loss: 0.4396
# Epoch: 12/50, Test Acc.: 74.60%
# Epoch: 13/50, Loss: 0.2882
# Epoch: 13/50, Test Acc.: 73.80%
# Epoch: 14/50, Loss: 0.2950
# Epoch: 14/50, Test Acc.: 74.87%
# Epoch: 15/50, Loss: 0.1529
# Epoch: 15/50, Test Acc.: 74.60%
# Epoch: 16/50, Loss: 0.2813
# Epoch: 16/50, Test Acc.: 74.57%
# Epoch: 17/50, Loss: 0.1917
# Epoch: 17/50, Test Acc.: 74.88%
# Epoch: 18/50, Loss: 0.2107
# Epoch: 18/50, Test Acc.: 74.10%
# Epoch: 19/50, Loss: 0.1372
# Epoch: 19/50, Test Acc.: 74.26%
# Epoch: 20/50, Loss: 0.3046
# Epoch: 20/50, Test Acc.: 74.67%
# Epoch: 21/50, Loss: 0.1773
# Epoch: 21/50, Test Acc.: 74.29%
# Epoch: 22/50, Loss: 0.0938
# Epoch: 22/50, Test Acc.: 74.17%
# Epoch: 23/50, Loss: 0.0492
# Epoch: 23/50, Test Acc.: 74.11%
# Epoch: 24/50, Loss: 0.0657
# Epoch: 24/50, Test Acc.: 73.65%
# Epoch: 25/50, Loss: 0.0454
# Epoch: 25/50, Test Acc.: 73.95%
# Epoch: 26/50, Loss: 0.0607
# Epoch: 26/50, Test Acc.: 73.79%
# Epoch: 27/50, Loss: 0.0644
# Epoch: 27/50, Test Acc.: 74.50%
# Epoch: 28/50, Loss: 0.0237
# Epoch: 28/50, Test Acc.: 74.17%
# Epoch: 29/50, Loss: 0.0416
# Epoch: 29/50, Test Acc.: 74.14%
# Epoch: 30/50, Loss: 0.0300
# Epoch: 30/50, Test Acc.: 74.12%
# Epoch: 31/50, Loss: 0.0720
# Epoch: 31/50, Test Acc.: 73.34%
# Epoch: 32/50, Loss: 0.0227
# Epoch: 32/50, Test Acc.: 73.78%
# Epoch: 33/50, Loss: 0.1213
# Epoch: 33/50, Test Acc.: 73.65%
# Epoch: 34/50, Loss: 0.0258
# Epoch: 34/50, Test Acc.: 73.27%
# Epoch: 35/50, Loss: 0.0664
# Epoch: 35/50, Test Acc.: 73.83%
# Epoch: 36/50, Loss: 0.1342
# Epoch: 36/50, Test Acc.: 74.31%
# Epoch: 37/50, Loss: 0.0304
# Epoch: 37/50, Test Acc.: 73.72%
# Epoch: 38/50, Loss: 0.0645
# Epoch: 38/50, Test Acc.: 72.87%
# Epoch: 39/50, Loss: 0.2088
# Epoch: 39/50, Test Acc.: 73.50%
# Epoch: 40/50, Loss: 0.0227
# Epoch: 40/50, Test Acc.: 73.81%
# Epoch: 41/50, Loss: 0.0271
# Epoch: 41/50, Test Acc.: 74.37%
# Epoch: 42/50, Loss: 0.0255
# Epoch: 42/50, Test Acc.: 74.26%
# Epoch: 43/50, Loss: 0.0030
# Epoch: 43/50, Test Acc.: 73.86%
# Epoch: 44/50, Loss: 0.0325
# Epoch: 44/50, Test Acc.: 73.20%
# Epoch: 45/50, Loss: 0.1256
# Epoch: 45/50, Test Acc.: 73.14%
# Epoch: 46/50, Loss: 0.0371
# Epoch: 46/50, Test Acc.: 73.78%
# Epoch: 47/50, Loss: 0.0841
# Epoch: 47/50, Test Acc.: 73.91%
# Epoch: 48/50, Loss: 0.1359
# Epoch: 48/50, Test Acc.: 74.25%
# Epoch: 49/50, Loss: 0.0859
# Epoch: 49/50, Test Acc.: 73.37%
# Epoch: 50/50, Loss: 0.0372
# Epoch: 50/50, Test Acc.: 73.86%
# CPU times: user 7h 6min 24s, sys: 51min 41s, total: 7h 58min 5s
# Wall time: 1h 4min 8s

# %%
util.plot_loss(losses_1, accuracies_1)

# %% [markdown]
# ## 4 conv + 1 fc layer model

# %%
cnn_2 = neural_nets.CNN(n_conv_layers=4,
                        filters=[64, 128, 256, 512],
                        kernel=[3, 3, 3, 3],
                        activation=['relu', 'relu', 'relu', 'relu'],
                        norm=[False, False, False, False],
                        pool=[2, 2, 2, 2],
                        input_channels=3,
                        fully_connected= [32],
                        input_dims=input_dimensions,
                        classes=target_classes)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print(cnn_2)
print()
total_params = sum([math.prod(list(p.size())) for p in list(cnn_2.parameters())])
print("Total number of parameters:", total_params)
# Out:
# CNN(
#   (conv_layers): ModuleList(
#     (0): Sequential(
#       (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=same)
#       (1): ReLU()
#       (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#     (1): Sequential(
#       (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=same)
#       (1): ReLU()
#       (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#     (2): Sequential(
#       (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=same)
#       (1): ReLU()
#       (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#     (3): Sequential(
#       (0): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=same)
#       (1): ReLU()
#       (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#   )
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (fc_layers): ModuleList(
#     (0): Linear(in_features=2048, out_features=32, bias=True)
#     (1): Linear(in_features=32, out_features=10, bias=True)
#   )
# )
#
# Total number of parameters: 1616874

# %% [markdown]
# ### Train

# %%
# %%time
cross_entropy = nn.CrossEntropyLoss()
adam_2 = optim.Adam(cnn_2.parameters(), lr=learning_rate)

losses_2, accuracies_2 = util.train_loop(model=cnn_2,
                                         loss_fn=cross_entropy,
                                         optimizer=adam_2,
                                         train_loader=train_loader,
                                         test_loader=test_loader,
                                         epochs=num_epochs,
                                         verbose=1)
# Out:
# Epoch: 1/50, Loss: 1.1678
# Epoch: 1/50, Test Acc.: 47.55%
# Epoch: 2/50, Loss: 1.2038
# Epoch: 2/50, Test Acc.: 60.33%
# Epoch: 3/50, Loss: 1.0596
# Epoch: 3/50, Test Acc.: 62.85%
# Epoch: 4/50, Loss: 0.6849
# Epoch: 4/50, Test Acc.: 68.43%
# Epoch: 5/50, Loss: 0.8874
# Epoch: 5/50, Test Acc.: 71.99%
# Epoch: 6/50, Loss: 0.5627
# Epoch: 6/50, Test Acc.: 74.56%
# Epoch: 7/50, Loss: 0.5348
# Epoch: 7/50, Test Acc.: 75.14%
# Epoch: 8/50, Loss: 0.3768
# Epoch: 8/50, Test Acc.: 75.24%
# Epoch: 9/50, Loss: 0.4065
# Epoch: 9/50, Test Acc.: 76.11%
# Epoch: 10/50, Loss: 0.1570
# Epoch: 10/50, Test Acc.: 74.45%
# Epoch: 11/50, Loss: 0.2823
# Epoch: 11/50, Test Acc.: 75.42%
# Epoch: 12/50, Loss: 0.1444
# Epoch: 12/50, Test Acc.: 74.17%
# Epoch: 13/50, Loss: 0.0600
# Epoch: 13/50, Test Acc.: 74.24%
# Epoch: 14/50, Loss: 0.0479
# Epoch: 14/50, Test Acc.: 75.90%
# Epoch: 15/50, Loss: 0.0561
# Epoch: 15/50, Test Acc.: 74.75%
# Epoch: 16/50, Loss: 0.2344
# Epoch: 16/50, Test Acc.: 74.79%
# Epoch: 17/50, Loss: 0.1750
# Epoch: 17/50, Test Acc.: 75.66%
# Epoch: 18/50, Loss: 0.2588
# Epoch: 18/50, Test Acc.: 75.05%
# Epoch: 19/50, Loss: 0.0743
# Epoch: 19/50, Test Acc.: 75.36%
# Epoch: 20/50, Loss: 0.0297
# Epoch: 20/50, Test Acc.: 74.71%
# Epoch: 21/50, Loss: 0.0188
# Epoch: 21/50, Test Acc.: 75.24%
# Epoch: 22/50, Loss: 0.0477
# Epoch: 22/50, Test Acc.: 75.73%
# Epoch: 23/50, Loss: 0.0827
# Epoch: 23/50, Test Acc.: 74.54%
# Epoch: 24/50, Loss: 0.0131
# Epoch: 24/50, Test Acc.: 75.33%
# Epoch: 25/50, Loss: 0.0042
# Epoch: 25/50, Test Acc.: 73.42%
# Epoch: 26/50, Loss: 0.0051
# Epoch: 26/50, Test Acc.: 74.66%
# Epoch: 27/50, Loss: 0.0359
# Epoch: 27/50, Test Acc.: 75.36%
# Epoch: 28/50, Loss: 0.1285
# Epoch: 28/50, Test Acc.: 75.11%
# Epoch: 29/50, Loss: 0.0517
# Epoch: 29/50, Test Acc.: 75.18%
# Epoch: 30/50, Loss: 0.0671
# Epoch: 30/50, Test Acc.: 74.87%
# Epoch: 31/50, Loss: 0.0359
# Epoch: 31/50, Test Acc.: 75.05%
# Epoch: 32/50, Loss: 0.0111
# Epoch: 32/50, Test Acc.: 75.33%
# Epoch: 33/50, Loss: 0.0436
# Epoch: 33/50, Test Acc.: 74.72%
# Epoch: 34/50, Loss: 0.0304
# Epoch: 34/50, Test Acc.: 75.32%
# Epoch: 35/50, Loss: 0.0153
# Epoch: 35/50, Test Acc.: 74.72%
# Epoch: 36/50, Loss: 0.0110
# Epoch: 36/50, Test Acc.: 75.29%
# Epoch: 37/50, Loss: 0.0565
# Epoch: 37/50, Test Acc.: 75.21%
# Epoch: 38/50, Loss: 0.0193
# Epoch: 38/50, Test Acc.: 75.70%
# Epoch: 39/50, Loss: 0.0021
# Epoch: 39/50, Test Acc.: 75.31%
# Epoch: 40/50, Loss: 0.0230
# Epoch: 40/50, Test Acc.: 74.27%
# Epoch: 41/50, Loss: 0.0291
# Epoch: 41/50, Test Acc.: 75.66%
# Epoch: 42/50, Loss: 0.0878
# Epoch: 42/50, Test Acc.: 74.34%
# Epoch: 43/50, Loss: 0.0064
# Epoch: 43/50, Test Acc.: 75.64%
# Epoch: 44/50, Loss: 0.0140
# Epoch: 44/50, Test Acc.: 74.96%
# Epoch: 45/50, Loss: 0.0035
# Epoch: 45/50, Test Acc.: 75.76%
# Epoch: 46/50, Loss: 0.0012
# Epoch: 46/50, Test Acc.: 75.16%
# Epoch: 47/50, Loss: 0.0019
# Epoch: 47/50, Test Acc.: 75.67%
# Epoch: 48/50, Loss: 0.0483
# Epoch: 48/50, Test Acc.: 74.59%
# Epoch: 49/50, Loss: 0.0456
# Epoch: 49/50, Test Acc.: 75.88%
# Epoch: 50/50, Loss: 0.0115
# Epoch: 50/50, Test Acc.: 75.84%
# CPU times: user 9h 8min 36s, sys: 52min 27s, total: 10h 1min 4s
# Wall time: 1h 19min 25s

# %%
util.plot_loss(losses_2, accuracies_2)

# %% [markdown]
# ## 3 VGG blocks + 1 fc layer model

# %%
cnn_3 = neural_nets.CNN(n_conv_layers=6,
                        filters=[64, 64, 128, 128, 256, 256],
                        kernel=[3, 3, 3, 3, 3, 3],
                        activation=['relu', 'relu', 'relu', 'relu', 'relu', 'relu'],
                        norm=[False, False, False, False, False, False],
                        pool=[0, 2, 0, 2, 0, 2],
                        input_channels=3,
                        fully_connected=[64],
                        input_dims=input_dimensions,
                        classes=target_classes)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print(cnn_3)
print()
total_params = sum([math.prod(list(p.size())) for p in list(cnn_3.parameters())])
print("Total number of parameters:", total_params)
# Out:
# CNN(
#   (conv_layers): ModuleList(
#     (0): Sequential(
#       (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=same)
#       (1): ReLU()
#     )
#     (1): Sequential(
#       (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=same)
#       (1): ReLU()
#       (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#     (2): Sequential(
#       (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=same)
#       (1): ReLU()
#     )
#     (3): Sequential(
#       (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=same)
#       (1): ReLU()
#       (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#     (4): Sequential(
#       (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=same)
#       (1): ReLU()
#     )
#     (5): Sequential(
#       (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=same)
#       (1): ReLU()
#       (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#   )
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (fc_layers): ModuleList(
#     (0): Linear(in_features=4096, out_features=64, bias=True)
#     (1): Linear(in_features=64, out_features=10, bias=True)
#   )
# )
#
# Total number of parameters: 1408266

# %% [markdown]
# ### Train

# %%
# %%time
cross_entropy = nn.CrossEntropyLoss()
adam_3 = optim.Adam(cnn_3.parameters(), lr=learning_rate)

losses_3, accuracies_3 = util.train_loop(model=cnn_3,
                                         loss_fn=cross_entropy,
                                         optimizer=adam_3,
                                         train_loader=train_loader,
                                         test_loader=test_loader,
                                         epochs=num_epochs,
                                         verbose=1)
# Out:
# Epoch: 1/50, Loss: 1.7195
# Epoch: 1/50, Test Acc.: 45.89%
# Epoch: 2/50, Loss: 1.1423
# Epoch: 2/50, Test Acc.: 60.24%
# Epoch: 3/50, Loss: 0.8111
# Epoch: 3/50, Test Acc.: 65.14%
# Epoch: 4/50, Loss: 0.8074
# Epoch: 4/50, Test Acc.: 69.94%
# Epoch: 5/50, Loss: 0.6270
# Epoch: 5/50, Test Acc.: 72.96%
# Epoch: 6/50, Loss: 0.5236
# Epoch: 6/50, Test Acc.: 76.10%
# Epoch: 7/50, Loss: 0.3328
# Epoch: 7/50, Test Acc.: 77.00%
# Epoch: 8/50, Loss: 0.5060
# Epoch: 8/50, Test Acc.: 77.28%
# Epoch: 9/50, Loss: 0.4602
# Epoch: 9/50, Test Acc.: 78.26%
# Epoch: 10/50, Loss: 0.2747
# Epoch: 10/50, Test Acc.: 78.66%
# Epoch: 11/50, Loss: 0.2187
# Epoch: 11/50, Test Acc.: 78.43%
# Epoch: 12/50, Loss: 0.2138
# Epoch: 12/50, Test Acc.: 78.29%
# Epoch: 13/50, Loss: 0.1498
# Epoch: 13/50, Test Acc.: 77.63%
# Epoch: 14/50, Loss: 0.1434
# Epoch: 14/50, Test Acc.: 78.09%
# Epoch: 15/50, Loss: 0.1031
# Epoch: 15/50, Test Acc.: 77.84%
# Epoch: 16/50, Loss: 0.0983
# Epoch: 16/50, Test Acc.: 78.53%
# Epoch: 17/50, Loss: 0.0441
# Epoch: 17/50, Test Acc.: 78.18%
# Epoch: 18/50, Loss: 0.0254
# Epoch: 18/50, Test Acc.: 77.81%
# Epoch: 19/50, Loss: 0.1327
# Epoch: 19/50, Test Acc.: 78.72%
# Epoch: 20/50, Loss: 0.0659
# Epoch: 20/50, Test Acc.: 77.23%
# Epoch: 21/50, Loss: 0.0698
# Epoch: 21/50, Test Acc.: 78.14%
# Epoch: 22/50, Loss: 0.0326
# Epoch: 22/50, Test Acc.: 77.80%
# Epoch: 23/50, Loss: 0.0424
# Epoch: 23/50, Test Acc.: 78.85%
# Epoch: 24/50, Loss: 0.0759
# Epoch: 24/50, Test Acc.: 77.78%
# Epoch: 25/50, Loss: 0.0418
# Epoch: 25/50, Test Acc.: 77.98%
# Epoch: 26/50, Loss: 0.0636
# Epoch: 26/50, Test Acc.: 78.13%
# Epoch: 27/50, Loss: 0.0148
# Epoch: 27/50, Test Acc.: 77.97%
# Epoch: 28/50, Loss: 0.1279
# Epoch: 28/50, Test Acc.: 78.35%
# Epoch: 29/50, Loss: 0.0905
# Epoch: 29/50, Test Acc.: 77.18%
# Epoch: 30/50, Loss: 0.0649
# Epoch: 30/50, Test Acc.: 77.44%
# Epoch: 31/50, Loss: 0.0234
# Epoch: 31/50, Test Acc.: 78.62%
# Epoch: 32/50, Loss: 0.0374
# Epoch: 32/50, Test Acc.: 77.72%
# Epoch: 33/50, Loss: 0.1017
# Epoch: 33/50, Test Acc.: 77.85%
# Epoch: 34/50, Loss: 0.0821
# Epoch: 34/50, Test Acc.: 77.91%
# Epoch: 35/50, Loss: 0.1196
# Epoch: 35/50, Test Acc.: 77.84%
# Epoch: 36/50, Loss: 0.1261
# Epoch: 36/50, Test Acc.: 77.81%
# Epoch: 37/50, Loss: 0.0849
# Epoch: 37/50, Test Acc.: 77.76%
# Epoch: 38/50, Loss: 0.0269
# Epoch: 38/50, Test Acc.: 78.61%
# Epoch: 39/50, Loss: 0.0747
# Epoch: 39/50, Test Acc.: 76.88%
# Epoch: 40/50, Loss: 0.0152
# Epoch: 40/50, Test Acc.: 78.07%
# Epoch: 41/50, Loss: 0.1404
# Epoch: 41/50, Test Acc.: 77.57%
# Epoch: 42/50, Loss: 0.0150
# Epoch: 42/50, Test Acc.: 78.26%
# Epoch: 43/50, Loss: 0.0371
# Epoch: 43/50, Test Acc.: 77.97%
# Epoch: 44/50, Loss: 0.0756
# Epoch: 44/50, Test Acc.: 77.64%
# Epoch: 45/50, Loss: 0.0006
# Epoch: 45/50, Test Acc.: 77.95%
# Epoch: 46/50, Loss: 0.0445
# Epoch: 46/50, Test Acc.: 77.69%
# Epoch: 47/50, Loss: 0.0916
# Epoch: 47/50, Test Acc.: 77.36%
# Epoch: 48/50, Loss: 0.0039
# Epoch: 48/50, Test Acc.: 78.14%
# Epoch: 49/50, Loss: 0.0429
# Epoch: 49/50, Test Acc.: 78.33%
# Epoch: 50/50, Loss: 0.0669
# Epoch: 50/50, Test Acc.: 76.72%
# CPU times: user 17h 18min 22s, sys: 2h 24min 44s, total: 19h 43min 7s
# Wall time: 2h 44min 40s

# %%
util.plot_loss(losses_3, accuracies_3)

# %% [markdown]
# ## 3 VGG blocks + 2 fc layers model

# %%
cnn_4 = neural_nets.CNN(n_conv_layers=6,
                        filters=[64, 64, 128, 128, 256, 256],
                        kernel=[3, 3, 3, 3, 3, 3],
                        activation=['relu', 'relu', 'relu', 'relu', 'relu', 'relu'],
                        norm=[False, False, False, False, False, False],
                        pool=[0, 2, 0, 2, 0, 2],
                        input_channels=3,
                        fully_connected=[32, 64],
                        input_dims=input_dimensions,
                        classes=target_classes)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print(cnn_4)
print()
total_params = sum([math.prod(list(p.size())) for p in list(cnn_4.parameters())])
print("Total number of parameters:", total_params)
# Out:
# CNN(
#   (conv_layers): ModuleList(
#     (0): Sequential(
#       (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=same)
#       (1): ReLU()
#     )
#     (1): Sequential(
#       (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=same)
#       (1): ReLU()
#       (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#     (2): Sequential(
#       (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=same)
#       (1): ReLU()
#     )
#     (3): Sequential(
#       (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=same)
#       (1): ReLU()
#       (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#     (4): Sequential(
#       (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=same)
#       (1): ReLU()
#     )
#     (5): Sequential(
#       (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=same)
#       (1): ReLU()
#       (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#   )
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (fc_layers): ModuleList(
#     (0): Linear(in_features=4096, out_features=32, bias=True)
#     (1): Linear(in_features=32, out_features=64, bias=True)
#     (2): Linear(in_features=64, out_features=10, bias=True)
#   )
# )
#
# Total number of parameters: 1279274

# %% [markdown]
# ### Train

# %%
# %%time
cross_entropy = nn.CrossEntropyLoss()
adam_4 = optim.Adam(cnn_4.parameters(), lr=learning_rate)

losses_4, accuracies_4 = util.train_loop(model=cnn_4,
                                         loss_fn=cross_entropy,
                                         optimizer=adam_4,
                                         train_loader=train_loader,
                                         test_loader=test_loader,
                                         epochs=num_epochs,
                                         verbose=1)
# Out:
# Epoch: 1/50, Loss: 1.5739
# Epoch: 1/50, Test Acc.: 43.52%
# Epoch: 2/50, Loss: 1.2488
# Epoch: 2/50, Test Acc.: 56.98%
# Epoch: 3/50, Loss: 0.9413
# Epoch: 3/50, Test Acc.: 64.18%
# Epoch: 4/50, Loss: 0.7268
# Epoch: 4/50, Test Acc.: 67.33%
# Epoch: 5/50, Loss: 0.9121
# Epoch: 5/50, Test Acc.: 70.67%
# Epoch: 6/50, Loss: 0.6089
# Epoch: 6/50, Test Acc.: 73.13%
# Epoch: 7/50, Loss: 0.4758
# Epoch: 7/50, Test Acc.: 75.87%
# Epoch: 8/50, Loss: 0.5149
# Epoch: 8/50, Test Acc.: 75.62%
# Epoch: 9/50, Loss: 0.4135
# Epoch: 9/50, Test Acc.: 77.08%
# Epoch: 10/50, Loss: 0.2412
# Epoch: 10/50, Test Acc.: 77.10%
# Epoch: 11/50, Loss: 0.2817
# Epoch: 11/50, Test Acc.: 76.74%
# Epoch: 12/50, Loss: 0.3258
# Epoch: 12/50, Test Acc.: 75.73%
# Epoch: 13/50, Loss: 0.1468
# Epoch: 13/50, Test Acc.: 76.93%
# Epoch: 14/50, Loss: 0.2147
# Epoch: 14/50, Test Acc.: 75.40%
# Epoch: 15/50, Loss: 0.0677
# Epoch: 15/50, Test Acc.: 77.27%
# Epoch: 16/50, Loss: 0.0713
# Epoch: 16/50, Test Acc.: 75.97%
# Epoch: 17/50, Loss: 0.1624
# Epoch: 17/50, Test Acc.: 75.95%
# Epoch: 18/50, Loss: 0.0358
# Epoch: 18/50, Test Acc.: 76.57%
# Epoch: 19/50, Loss: 0.0496
# Epoch: 19/50, Test Acc.: 77.10%
# Epoch: 20/50, Loss: 0.1930
# Epoch: 20/50, Test Acc.: 76.52%
# Epoch: 21/50, Loss: 0.0583
# Epoch: 21/50, Test Acc.: 76.22%
# Epoch: 22/50, Loss: 0.1028
# Epoch: 22/50, Test Acc.: 76.42%
# Epoch: 23/50, Loss: 0.0235
# Epoch: 23/50, Test Acc.: 76.53%
# Epoch: 24/50, Loss: 0.0922
# Epoch: 24/50, Test Acc.: 76.22%
# Epoch: 25/50, Loss: 0.0808
# Epoch: 25/50, Test Acc.: 76.71%
# Epoch: 26/50, Loss: 0.0473
# Epoch: 26/50, Test Acc.: 76.23%
# Epoch: 27/50, Loss: 0.0566
# Epoch: 27/50, Test Acc.: 76.58%
# Epoch: 28/50, Loss: 0.0409
# Epoch: 28/50, Test Acc.: 76.42%
# Epoch: 29/50, Loss: 0.0663
# Epoch: 29/50, Test Acc.: 76.15%
# Epoch: 30/50, Loss: 0.0551
# Epoch: 30/50, Test Acc.: 77.11%
# Epoch: 31/50, Loss: 0.0068
# Epoch: 31/50, Test Acc.: 76.70%
# Epoch: 32/50, Loss: 0.0714
# Epoch: 32/50, Test Acc.: 76.41%
# Epoch: 33/50, Loss: 0.0043
# Epoch: 33/50, Test Acc.: 75.63%
# Epoch: 34/50, Loss: 0.0566
# Epoch: 34/50, Test Acc.: 75.21%
# Epoch: 35/50, Loss: 0.0660
# Epoch: 35/50, Test Acc.: 76.74%
# Epoch: 36/50, Loss: 0.0528
# Epoch: 36/50, Test Acc.: 76.88%
# Epoch: 37/50, Loss: 0.0466
# Epoch: 37/50, Test Acc.: 76.29%
# Epoch: 38/50, Loss: 0.0126
# Epoch: 38/50, Test Acc.: 76.97%
# Epoch: 39/50, Loss: 0.0404
# Epoch: 39/50, Test Acc.: 76.25%
# Epoch: 40/50, Loss: 0.0022
# Epoch: 40/50, Test Acc.: 76.58%
# Epoch: 41/50, Loss: 0.0027
# Epoch: 41/50, Test Acc.: 76.51%
# Epoch: 42/50, Loss: 0.0121
# Epoch: 42/50, Test Acc.: 77.06%
# Epoch: 43/50, Loss: 0.0277
# Epoch: 43/50, Test Acc.: 76.08%
# Epoch: 44/50, Loss: 0.0638
# Epoch: 44/50, Test Acc.: 76.56%
# Epoch: 45/50, Loss: 0.0904
# Epoch: 45/50, Test Acc.: 76.98%
# Epoch: 46/50, Loss: 0.0290
# Epoch: 46/50, Test Acc.: 77.24%
# Epoch: 47/50, Loss: 0.0020
# Epoch: 47/50, Test Acc.: 77.30%
# Epoch: 48/50, Loss: 0.0375
# Epoch: 48/50, Test Acc.: 76.91%
# Epoch: 49/50, Loss: 0.0565
# Epoch: 49/50, Test Acc.: 76.48%
# Epoch: 50/50, Loss: 0.0600
# Epoch: 50/50, Test Acc.: 76.40%
# CPU times: user 17h 20min 41s, sys: 2h 25min 4s, total: 19h 45min 45s
# Wall time: 2h 45min 39s

# %%
util.plot_loss(losses_4, accuracies_4)
